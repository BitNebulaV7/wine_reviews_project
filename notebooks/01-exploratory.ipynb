# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

RAW = Path("../data/raw/winemag-data-130k-v2.csv")

def load_data(filepath, dtypes=None):
    try:
        df = pd.read_csv(filepath, dtype=dtypes)
        print("✅ File loaded successfully.")
        print("🔍 Missing values per column:")
        print(df.isnull().sum())
        return df
    except Exception as e:
        print(f"❌ Error loading file: {e}")
        return None

# %%
df = load_data(RAW)
df.head()
# Out:
# ✅ File loaded successfully.
# 🔍 Missing values per column:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# ...

# %%
def summarise_df(df):
    num_cols,num_rows = df.shape
    print(f"🔢 Rows: {num_rows}, Columns: {num_cols}")

    missing_count = df.isnull().sum()
    missing_percent = (missing_count / len(df)) * 100

    unique_counts = df.nunique()

    summary = pd.DataFrame({
        'missing count' : missing_count,
        'missing %' : missing_percent.round(2),
        'unique Values' : unique_counts

    }).sort_values(by='missing %', ascending=False)

    return summary

# %%
summary_table = summarise_df(df)
summary_table.head(10)
# Out:
# 🔢 Rows: 14, Columns: 129971
#                        missing count  missing %  unique Values
# region_2                       79460      61.14             17
# designation                    37465      28.83          37979
# taster_twitter_handle          31213      24.02             15
# taster_name                    26244      20.19             19
# region_1                       21247      16.35           1229
# price                           8996       6.92            390
# province                          63       0.05            425
# country                           63       0.05             43
# Unnamed: 0                         0       0.00         129971
# description                        0       0.00         119955

# %%
def convert_type(df,schema):
    for column, dtype in schema.items():
        try:
            df[column] = df[column].astype(dtype)
            print(f'Convert {column} to {dtype}')
        except Exception as e:
            print(f"⚠️ Could not convert {column} to {dtype}: {e}")
    return df

# %%
schema ={
    'price':'float',
     'points': 'int',
    'country': 'string',
    'province': 'string',
    'variety': 'string'
}

df = convert_type(df,schema)
# Out:
# Convert price to float
# Convert points to int
# Convert country to string
# Convert province to string
# Convert variety to string

# %%
df.drop(columns=['region_2','taster_twitter_handle'],inplace=True)

# %%
median_price = df['price'].median()
df['price'] = df['price'].fillna(median_price)

mode_country = df['country'].mode()[0]
df['country'] = df['country'].fillna(mode_country)

mode_province = df['province'].mode()[0]
df['province'] = df['province'].fillna(mode_province)

mode_variety = df['variety'].mode()[0]
df['variety'] = df['variety'].fillna(mode_variety)

df['taster_name'] = df['taster_name'].fillna('Unknown')
